# %% [markdown]
# # Fetching different dataset using API

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# ### Dataset 1: Company name with website

# %%
import requests

url = "https://job-listings2.p.rapidapi.com/api/v1/companies"

querystring = {"page":"1","limit":"20"}

headers = {
	"x-rapidapi-key": "da6a799a5cmshaa5843035bc8640p12de0ajsn7c2507260e3d",
	"x-rapidapi-host": "job-listings2.p.rapidapi.com"
}

response = requests.get(url, headers=headers, params=querystring)

df_orgi = pd.DataFrame(response.json()['companies']) #inside json dictionary companies key has the column what we need
df_selected = df_orgi[['name', 'board', 'website']] #selecting only 3 rows

# %%
import http.client

conn = http.client.HTTPSConnection("beer9.p.rapidapi.com")

headers = {
    'x-rapidapi-key': "da6a799a5cmshaa5843035bc8640p12de0ajsn7c2507260e3d",
    'x-rapidapi-host': "beer9.p.rapidapi.com"
}

conn.request("GET", "/?name=Berkshire%20Easy%20Lite", headers=headers)

res = conn.getresponse()
data = res.read()

print(data.decode("utf-8"))
# Out:
# {"code":200,"error":false,"data":{"sku":"100001","name":"Berkshire Easy Lite","brewery":"Berkshire Brewing Company","rating":"","category":"Beer","sub_category_1":"Ale","sub_category_2":"IPA","sub_category_3":"New England \/ Hazy IPA","description":"Everybody likes easy, so we made this NEIPA easy to like with Citra, Amarillo and Simcoe hops, a medium body and fermented it with a German style ale yeast. This double dry-hopped brew has a hazy straw color and a clean finish to make Easy Like a session-able NEIPA, easy for you to enjoy any time. #EasyLikeNEIPA","region":"Massachusetts","country":"United States","abv":"4.50%","ibu":"20","calories_per_serving_12oz":"","carbs_per_serving_12oz":"","tasting_notes":"","food_pairing":"Grilled chicken, Salad, Light pasta dishes","suggested_glassware":"Snifter\/Goblet\/Chalice","serving_temp_f":"45-50\u00b0 F","serving_temp_c":"7.2-10.0\u00b0 C","beer_type":"","features":""}}

# %%
import requests

url = "https://beer9.p.rapidapi.com/"

querystring = {"name":"Berkshire Easy Lite"}

headers = {
	"x-rapidapi-key": "da6a799a5cmshaa5843035bc8640p12de0ajsn7c2507260e3d",
	"x-rapidapi-host": "beer9.p.rapidapi.com"
}

response = requests.get(url, headers=headers, params=querystring)

print(response.json())
# Out:
# {'code': 200, 'error': False, 'data': {'sku': '100001', 'name': 'Berkshire Easy Lite', 'brewery': 'Berkshire Brewing Company', 'rating': '', 'category': 'Beer', 'sub_category_1': 'Ale', 'sub_category_2': 'IPA', 'sub_category_3': 'New England / Hazy IPA', 'description': 'Everybody likes easy, so we made this NEIPA easy to like with Citra, Amarillo and Simcoe hops, a medium body and fermented it with a German style ale yeast. This double dry-hopped brew has a hazy straw color and a clean finish to make Easy Like a session-able NEIPA, easy for you to enjoy any time. #EasyLikeNEIPA', 'region': 'Massachusetts', 'country': 'United States', 'abv': '4.50%', 'ibu': '20', 'calories_per_serving_12oz': '', 'carbs_per_serving_12oz': '', 'tasting_notes': '', 'food_pairing': 'Grilled chicken, Salad, Light pasta dishes', 'suggested_glassware': 'Snifter/Goblet/Chalice', 'serving_temp_f': '45-50° F', 'serving_temp_c': '7.2-10.0° C', 'beer_type': '', 'features': ''}}

# %%
import requests

url = "https://yahoo-finance15.p.rapidapi.com/api/v2/markets/stock/history"

querystring = {"symbol":"AAPL","interval":"1m","limit":"640"}

headers = {
	"x-rapidapi-key": "da6a799a5cmshaa5843035bc8640p12de0ajsn7c2507260e3d",
	"x-rapidapi-host": "yahoo-finance15.p.rapidapi.com"
}

response = requests.get(url, headers=headers, params=querystring)

print(response.json())
# Out:
# {'meta': {'version': 'v2.0', 'status': 200, 'copywrite': 'https://apicalls.io', 'ticker': 'AAPL', 'interval': '1m', 'dividend': False}, 'body': [{'timestamp': '2025-06-12 14:27', 'timestamp_unix': 1749752820, 'open': 198.967, 'high': 198.975, 'low': 198.665, 'close': 198.73, 'volume': 134326}, {'timestamp': '2025-06-12 14:28', 'timestamp_unix': 1749752880, 'open': 198.74, 'high': 198.87, 'low': 198.71, 'close': 198.8, 'volume': 60228}, {'timestamp': '2025-06-12 14:29', 'timestamp_unix': 1749752940, 'open': 198.8, 'high': 198.82, 'low': 198.725, 'close': 198.75, 'volume': 44043}, {'timestamp': '2025-06-12 14:30', 'timestamp_unix': 1749753000, 'open': 198.76, 'high': 198.79, 'low': 198.72, 'close': 198.75, 'volume': 63644}, {'timestamp': '2025-06-12 14:31', 'timestamp_unix': 1749753060, 'open': 198.75, 'high': 198.78, 'low': 198.64, 'close': 198.66, 'volume': 71381}, {'timestamp': '2025-06-12 14:32', 'timestamp_unix': 1749753120, 'open': 198.65, 'high': 198.65, 'low': 198.545, 'close':
# ...

# %%
import requests

url = "https://imdb232.p.rapidapi.com/api/news/get-by-category"

querystring = {"limit":"25","category":"CELEBRITY"}

headers = {
	"x-rapidapi-key": "da6a799a5cmshaa5843035bc8640p12de0ajsn7c2507260e3d",
	"x-rapidapi-host": "imdb232.p.rapidapi.com"
}

response = requests.get(url, headers=headers, params=querystring)

# print(response.json())
pd.DataFrame(response.json()['data']['news']['edges'])
# Out:
#                                                  node
# 0   {'__typename': 'News', 'id': 'ni65336523', 'by...
# 1   {'__typename': 'News', 'id': 'ni65336386', 'by...
# 2   {'__typename': 'News', 'id': 'ni65334838', 'by...
# 3   {'__typename': 'News', 'id': 'ni65335122', 'by...
# 4   {'__typename': 'News', 'id': 'ni65336829', 'by...
# 5   {'__typename': 'News', 'id': 'ni65336830', 'by...
# 6   {'__typename': 'News', 'id': 'ni65336731', 'by...
# 7   {'__typename': 'News', 'id': 'ni65336732', 'by...
# 8   {'__typename': 'News', 'id': 'ni65336733', 'by...
# 9   {'__typename': 'News', 'id': 'ni65336583', 'by...
# 10  {'__typename': 'News', 'id': 'ni65336584', 'by...
# 11  {'__typename': 'News', 'id': 'ni65336272', 'by...
# 12  {'__typename': 'News', 'id': 'ni65336216', 'by...
# 13  {'__typename': 'News', 'id': 'ni65336217', 'by...
# 14  {'__typename': 'News', 'id': 'ni65336168', 'by...
# 15  {'__typename': 'News', 'id': 'ni65336169', 'by...
# ...

# %% [markdown]
# ### Subdomains Dataset

# %%
import requests

url = "https://subdomain-finder3.p.rapidapi.com/v1/subdomain-finder/"

querystring = {"domain":"rapidapi.com"}

headers = {
	"x-rapidapi-key": "da6a799a5cmshaa5843035bc8640p12de0ajsn7c2507260e3d",
	"x-rapidapi-host": "subdomain-finder3.p.rapidapi.com"
}

response = requests.get(url, headers=headers, params=querystring)

df_temp = response.json()['subdomains']

df_dmn = pd.DataFrame(df_temp) #converting json into pandas dataframe
print(df_dmn.head())

subdomain = df_dmn.to_csv('subdomains.csv', index=False)
# Out:
#                  subdomain              ip  cloudflare
# 0         amp.rapidapi.com    172.66.41.24        True
# 1        blog.rapidapi.com    172.66.41.24        True
# 2  blog-proxy.rapidapi.com  162.159.134.42        True
# 3         cdn.rapidapi.com   18.165.227.64       False
# 4     courses.rapidapi.com    172.66.41.24        True
